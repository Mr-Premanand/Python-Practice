# %% [markdown]
# <a href="https://colab.research.google.com/github/Mr-Premanand/Python-Practice/blob/main/Introduction_to_Data_Visualization_Problem_solved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <u> Use only those concepts which have been taught till now </u>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Use the file company_sales_data.csv

# %%
import numpy as np
import pandas as pd

from datetime import datetime

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Data/company_sales_data.csv")

# %%
df.head()
# Out:
#    month_number  facecream  facewash  ...  moisturizer  total_units  total_profit
# 0             1       2500      1500  ...         1500        21100        211000
# 1             2       2630      1200  ...         1200        18330        183300
# 2             3       2140      1340  ...         1340        22470        224700
# 3             4       3400      1130  ...         1130        22270        222700
# 4             5       3600      1740  ...         1740        20960        209600
#
# [5 rows x 9 columns]

# %% [markdown]
# # <u>**Problem 1**</u>
#
# ### Plot the total profit across the months
#
# * X label name = Month Number
# * Y label name = Total profit

# %%
plt.rcParams['figure.figsize'] = (10, 5)

# %%
# Your code here
profit_plot=df[["total_profit","month_number"]]

profit_plot.plot()
plt.title("Total profit across the months")
plt.xlabel("Month Number")
plt.ylabel("Total profit")
# Out:
# Text(0, 0.5, 'Total profit')

# %% [markdown]
# # <b><u>Problem 2 </u></b>
#
# ### Read face cream and facewash product sales data and show it using the bar chart. The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.

# %%
# Your code here
bar=df[["facecream","facewash","month_number"]]

bar=bar.set_index("month_number")
bar.plot.bar()
plt.xlabel("Month")
plt.ylabel("No of lot sale")
plt.title("Sale data")
# Out:
# Text(0.5, 1.0, 'Sale data')

# %% [markdown]
# # <b><u>Problem 3</u></b>
#
# ### Display the number of units sold per month for each product using multiline plots. (i.e. separate plotline for each product ).

# %%
# Your code here
sale_for_each_product=df[['month_number', 'facecream', 'facewash', 'toothpaste', 'bathingsoap',
       'shampoo', 'moisturizer']]
sale_for_each_product=sale_for_each_product.set_index("month_number")

sale_for_each_product.plot()
plt.title("Number of units sold per month")
plt.xlabel("Month")
plt.ylabel("No of units")
# Out:
# Text(0, 0.5, 'No of units')
